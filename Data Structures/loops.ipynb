# %%
#fibonacci series
n = int(input("enter a no."))
a = 0
b = 1

for i in range(n):
    print(a,end = " ")

    c = a+b
    a=b
    b=c
# Out:
# 0 1 1 2 3 5

# %%
#reverse of a no.
num = int(input("enter a no."))
orginal_num = num   
reverse_num = 0
while num > 0:
    digit = num % 10
    reverse_num = reverse_num * 10 + digit
    num = num // 10 
if orginal_num == reverse_num:
    print(orginal_num,"is a pallindrome")
else:
    print(orginal_num,"is not a pallindrome")

# %%
end = int(input("enter end range"))
prime_lst =[]

for num in range(2,end+1):
    for i in range(2,num):
        if num%i == 0:
            break
    else:
        prime_lst.append(num)
print(prime_lst)
# Out:
# [2, 3, 5, 7, 11]

# %%
import math

# %%
print(math.gcd(10,20))
print(math.lcm(5,10))
print(math.factorial(9))
print(math.sin(0))
print(math.pi)
print(math.e)
print(math.pow(2,3))
# Out:
# 10
# 10
# 362880
# 0.0
# 3.141592653589793
# 2.718281828459045
# 8.0

# %%
from random import random, randint, shuffle, choice

# %%
print("numbers between 0 and 1", random())
print("number between given range ", randint(1,50))
print("select element from your set of choice ",choice([2,5,4,6,7]))
names=["jack","jill","jane","john"]
shuffle(names)
print("print shuffle list", names)
# Out:
# numbers between 0 and 1 0.2089014897690591
# number between given range  1
# select element from your set of choice  6
# print shuffle list ['jack', 'jill', 'jane', 'john']

# %%
from datetime import datetime as dt

# %%
print("current date and time is", dt.now())
print("current date is",dt.now().date())
print("current time is", dt.now().time())
print("current year is ",dt.now().year)
print("current month is", dt.now().month)
print("current day is ", dt.now().day)
print("current hour is ", dt.now().hour)
print("current minute is ", dt.now().minute)
print("current second is ", dt.now().second)
print("current microsecond is",dt.now().microsecond)
# Out:
# current date and time is 2026-06-22 14:46:40.238969
# current date is 2026-06-22
# current time is 14:46:40.239609
# current year is  2026
# current month is 6
# current day is  22
# current hour is  14
# current minute is  46
# current second is  40
# current microsecond is 240304

# %%
print("formatted date is",dt.now().strftime("%Y-%m-%d"))
print("formatted time is",dt.now().strftime("%H:%M:%S"))
print("Current month name",dt.now().strftime("%b"))
print("current month name",dt.now().strftime("%A"))
print("current month name",dt.now().strftime("%a"))
# Out:
# formatted date is 2026-06-22
# formatted time is 14:55:10
# Current month name Jun
# current month name Monday
# current month name Mon

# %% [markdown]
# # read from w3schools.com
