# %%
poem = '''johny johny yes papa 
eating sugar no papa 
telling lies no papa 
open your mouth ha ha ha'''
print(poem)
# Out:
# johny johny yes papa
# eating sugar no papa
# telling lies no papa
# open your mouth ha ha ha

# %% [markdown]
# ## String

# %%
name = 'palak'
print(name)
# Out:
# palak

# %% [markdown]
# ## Lists

# %%
fruits =['apple' , 'banana',' orange',' mango']
print(fruits)
# Out:
# ['apple', 'banana', ' orange', ' mango']

# %% [markdown]
# ## Sets

# %%
a={1,2,3,4,5,6,6,4,3,2,1}
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ## Dictionaries

# %%
student = {
   ' name ': 'palak',
    'age': 21,
    'course':'python',
}
print(student)
# Out:
# {' name ': 'palak', 'age': 21, 'course': 'python'}

# %%
type(poem) #to check the datatype of variable
# Out:
# str

# %% [markdown]
# TYPE CASTING - is a process of converting one datatype to another datatype.
# - int() - to convert to integer
# - float() - to convert to float
# - str() - to convert to string
# - list() - to convert to list
# - tuple() - to convert to tuple
# - set() - to convert to set

# %%
a = 10
type(a)
# Out:
# int

# %%
a =20 
b =str(a)
type(b)
# Out:
# str

# %%
a = 10 
b = 'hello'
c = str(a)
print(b+c) #concatenation of string
# Out:
# hello10

# %%
a = input ('enter a value')
b= input ('enter a value')
print(a+b) #concatenation of string is takes as a defeult input is string
# Out:
# 1020

# %%
a = int(input ('enter a value'))
b= int(input ('enter a value'))
print(a+b)
# Out:
# 50

# %%
a = 10
b = 20 
sum = a + b
print("sum of", a, "and", b, "is", sum)
print(f'sum of {a} and {b} is {sum}') #f string formatting
# Out:
# sum of 10 and 20 is 30
# sum of 10 and 20 is 30

# %% [markdown]
# to find type of data type

# %%
a = 10 
type(a)
# Out:
# int

# %%
a =29
print(a^3)
print (a**3)
# Out:
# 30
# 24389

# %% [markdown]
# area of cricle

# %%
r = 5 
pi = 3.14
area = pi * r**2
print(f'area of circle with radius {r} is {area}')
# Out:
# area of circle with radius 5 is 78.5

# %%
r= 10
a = 20
area_of_square = a**2
area_of_rectangle = a*r
print(f'area of square with side {a} is {area_of_square}')
print(f'area of rectangle with length {a} and breadth {r} is {area_of_rectangle}')
# Out:
# area of square with side 20 is 400
# area of rectangle with length 20 and breadth 10 is 200

# %%
sal = 50000
hra =(5*sal)/100
da = (10*sal)/100
print(f'hra is {hra}')
print(f'da is {da}')
print(f'total salary is {sal+hra+da}')
# Out:
# hra is 2500.0
# da is 5000.0
# total salary is 57500.0

# %%
p = int(input('enter the principle amount'))
r = int(input('enter the rate of interest'))
t = int(input('enter the time in years'))
si =(p*r*t)/100
print(f'simple interest is {si}')
# Out:
# simple interest is 20.0

# %% [markdown]
# check no. is poistive or not

# %%
a = int(input('enter a no'))
if a%2 ==0 :
    print (f'{a} is even')
else:
   print(f'{a} is odd')
# Out:
# 8 is even
