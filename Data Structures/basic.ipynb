# %%
print(1234)
# Out:
# 1234

# %% [markdown]
# # heading1

# %% [markdown]
# ## h2

# %% [markdown]
#  `Higlighted text`

# %% [markdown]
# - points1
# - points2
# - points3
#    - subpoint1
#        - subpoint2
#           - subpoint3

# %%
a =10
b=3
print(a+b)
print(a/b)
print(a*b)
print(a-b)
print(a**b)
print(a//b)
print(a%b)
# Out:
# 13
# 3.3333333333333335
# 30
# 7
# 1000
# 3
# 1

# %%
a= 12
b=5
c=7
a>b and a>c
# Out:
# True

# %%
a<b or a>c
# Out:
# True

# %%
not(a>b and a>c)
# Out:
# False

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
fruits =['apple','banana','grapes']
'banana' in fruits
'orange' in fruits
# Out:
# False
