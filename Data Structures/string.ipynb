# %%
x ="all is well"
x.upper()
# Out:
# 'ALL IS WELL'

# %%
x.lower()
# Out:
# 'all is well'

# %%
x.capitalize()
# Out:
# 'All is well'

# %%
x.title()
# Out:
# 'All Is Well'

# %%
x*5
# Out:
# 'all is wellall is wellall is wellall is wellall is well'

# %%
poem ='''Johny johny yes papa
eating sugar no '''

# %%
x.startswith("a")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x.startswith("a")
#
# NameError: name 'x' is not defined

# %%
"hello".isalpha()
# Out:
# True

# %%
"12345".isdigit()
# Out:
# True

# %%
"hello123".isalnum()
# Out:
# True

# %%
"hello world".swapcase()
# Out:
# 'HELLO WORLD'

# %%
len(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(x)
#
# NameError: name 'x' is not defined

# %%
"hello".index('e')
# Out:
# 1

# %%
student = {"name":"palak","age":18}
print(student)
# Out:
# {'name': 'palak', 'age': 18}
