# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#total accident by state 
fig = px .bar(df, x='abbrev' , y='total',
              title = 'statewise car accidents',
              labels

# %%
import plotly.express as px

# %%
 # top10 = df.nlargest(10,'is_premuim')
top10 = df.sort_values('ins_premuim' , ascending = True).tail(10)
fig =px.bar(top10, x='abbrev' , y='ins_permuim',
            title = 'top10 states by insurance permuin',
            color = 'abbrev',
            template ='plotly_dark')
fig.show()

# %% [markdown]
# - scatter plot of alcohol vs speeding accidents
# - line chart of statewise total accidents

# %%
fig = px.line(df, x='abbrev' y ='total,
              template='plotly_dark', 
              title = "satawise accidents",
              labels = {'abbrev : 'state', 'total', }
               )
fig.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = px.pie(df, values='speeding', names='abbrev',
             template = 'plotly_dark',
             color_discrete_sequence=px.colors.sequential.Burg)
fig.update_traces(textposition='inside')
fig.update_layout(title= {'x' :0.5})
fig.show()
